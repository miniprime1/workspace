# %% [markdown]
# # Popcat (popcat.py)

# %% [markdown]
# This is a Popcat program for the Command-line interface made in python.
# This program prints a Popcat with mouth open and a Popcat with mouth closed at 0.5 seconds (500 milliseconds) intervals.

# %%
import time
import os

clrscr = lambda: os.system('cls' if os.name in ('nt', 'dos') else 'clear')
sleep = lambda: time.sleep(0.5)

popcat_openmouth_ascii = " \
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n \
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n \
@@@,,,,,@@@@@@@@@@@@@@@@@@@@@@@@@@@@@,,,,.@@@@@@@@@\n \
@@//((///,,,@@@@@@@@@@@@@@@@@@@@@(**,,,,,,@@@@@@@@@\n \
@@((((/(//(/,,@@@@@@@/,,,......,///*,,****@@@@@@@@@\n \
@*(((((((//(((((((((/*,.         ..//(****,@@@@@@@@\n \
@*/((((((((/((((((/,,/##*.   .,*////,....*,,@@@@@@@\n \
@@***((((((((((((//(*.   .,*/(#%%%%%%#(*....,,@@@@@\n \
@@@*,***/(((((((/,....,*(%&@@@@@@@@@@@@@&#(/***.@@2\n \
@@@@,,*,*/((((%#/****/#@@@@@@@@@@@@@@@@@@@@%((/*@@@\n \
@@@@@ *(#####%%(////(&@@@@@@@@@@@@@@@@@@@@@@%#(/*@@\n \
@@@@@@@*#%&&&%((/((#&@@@@@@@@@@@@@@@@@@@@@@@%#(/*@@\n \
@@@@@@@*/%&&&#((/((#@@@&&&&&@@@@@@@@@&&&&&&&%#(//@@\n \
@@@@@@@@(*&&&%#(((((%&&&&&&&&&&&&&&&&&&&&&&%#((/(@@\n \
@@@@@@@@@,*%&%((/(/(((#%%%&&&&&&&&&&&&&&%%##((/*@@@\n \
@@@@@@@@@@*//((///////(((###%%%%%%%%%%%##((((/,@@@@\n \
@@@@@@@@@.*//////////////(((((((#####(((((((*@@@@@@\n \
@@@@@@@@@***///////////(/((((((((((((((((((*,@@@@@@\n \
@@@@@@@@*****///////////((((((((((((((((((/*@@@@@@@\n \
@@@@@@@,*****////////////////(((((((((((((/*(@@@@@@\n \
@@@@@@,******///*///////////((((/(((((((////(@@@@@@\n \
@@@@@@,**********////////////(((/(((((((////(@@@@@@\n \
@@@@@.**************/////////////(((((((////@@@@@@@\n \
@@@@@,***************////////////(((((((/(//@@@@@@@\n \
@@@@@,**************//////////////((/(((////@@@@@@@\n \
@@@@@,***////***//**/**/////////////(///(((/@@@@@@@\n \
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n \
"

popcat_closemouth_ascii = " \
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n \
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n \
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@,,,,,@@@@@@@@\n \
@@@@@*//((//*/@@@@@@@@@@@@@@@@@@@@@@**,,,,,%@@@@@@@\n \
@@@@@*(((////(/*,@@@@@@@@@@@@@@@@@///*,,,**%@@@@@@@\n \
@@@@@*((((((///((((///////**.     .*/******@@@@@@@@\n \
@@@@@(/(((((((//(((((//*..          .,*//**@@@@@@@@\n \
@@@@@@(**((((((///////*(####*       ,#%%#/*,@@@@@@@\n \
@@@@@@@/****(((((((((/,,,((#/,        .....,//@@@@@\n \
@@@@@@@@,,**/((((##%#(*,,,...  ..,////.....,*//*@@@\n \
@@@@@@@@@,/#####%%%%#(///////((((/((((((((((((//(@@\n \
@@@@@@@@@@,(%%%&&&%##///(((((((((((((((((((((((/,@@\n \
@@@@@@@@@@@*#%&&&&###(///((((((((((((((((((((((*#@@\n \
@@@@@@@@@@@@*#&&&&%%((////(((((((((((((((((((/*@@@@\n \
@@@@@@@@@@@@@,(%%&#((////////(((((((((((((((/,@@@@@\n \
@@@@@@@@@@@@@,////////////////(((((((((((((/*,@@@@@\n \
@@@@@@@@@@@@***//////////////((((((((((((((/*,@@@@@\n \
@@@@@@@@@@@***//////////////////(((((((((((/**@@@@@\n \
@@@@@@@@@@(****///////////////////((((((((///*@@@@@\n \
@@@@@@@@@@******////////////////////(((((((//**@@@@\n \
@@@@@@@@@,******////////////////////((((((////(@@@@\n \
@@@@@@@@@********////////////////////(((((////*@@@@\n \
@@@@@@@@.************/////////////////(((((///*@@@@\n \
@@@@@@@@,************////////////////((((/////*@@@@\n \
@@@@@@@@,************////////////////((((/////,@@@@\n \
@@@@@@@@***/*******///////////////////////////,%@@@\n \
@@@@@@@@************//////////////////////////,,@@@\n \
"

while True:
    clrscr()
    print(popcat_closemouth_ascii)
    sleep()
    clrscr()
    print(popcat_openmouth_ascii)
    sleep()
