# %% [markdown]
# # Solve and Plot Wave Equation in Wolfram

# %%
wevq = D[u[x, t], {t, 2}] == D[u[x, t], {x, 2}]
# Out:
#  (0,2)           (2,0)
# u     [x, t] == u     [x, t]

# %%
ini = {u[x, 0] == Exp[-x^2], Derivative[0, 1][u][x, 0] == 1}
# Out:
#                2
#              -x    (0,1)
# {u[x, 0] == E   , u     [x, 0] == 1}

# %%
sol = DSolveValue[{wevq, ini}, u[x, t], {x, t}]
# Out:
#                       2            2
#              -(-t + x)     -(t + x)
#             E           + E
# Piecewise[{{------------------------ + t, t >= 0}}, Indeterminate]
#                        2

# %%
Plot3D[sol, {x, -5, 5}, {t, 0, 5}]
# Out:
# -Graphics3D-
